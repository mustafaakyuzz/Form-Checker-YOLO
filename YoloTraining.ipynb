# %%
# !rm -rf /content/drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip /content/drive/MyDrive/yolo_datasets/Dataset.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/yolo_datasets/Dataset.zip
#   inflating: /content/dataset/data.yaml
#    creating: /content/dataset/train/
#    creating: /content/dataset/train/images/
#   inflating: /content/dataset/train/images/pushup1_frame100.jpg
#   inflating: /content/dataset/train/images/pushup1_frame110.jpg
#   inflating: /content/dataset/train/images/pushup1_frame120.jpg
#   inflating: /content/dataset/train/images/pushup1_frame130.jpg
#   inflating: /content/dataset/train/images/pushup1_frame20.jpg
#   inflating: /content/dataset/train/images/pushup1_frame30.jpg
#   inflating: /content/dataset/train/images/pushup1_frame40.jpg
#   inflating: /content/dataset/train/images/pushup1_frame50.jpg
#   inflating: /content/dataset/train/images/pushup1_frame60.jpg
#   inflating: /content/dataset/train/images/pushup1_frame70.jpg
#   inflating: /content/dataset/train/images/pushup1_frame80.jpg
#   inflating: /content/dataset/train/images/pushup1_frame90.jpg
# ...

# %%
yaml_content = '''
train: /content/dataset/train
val: /content/dataset/valid

nc: 1
names: ['pushup']
'''

with open ('/content/dataset/data.yaml', 'w') as f:
  f.write(yaml_content)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

model.train(data = 'dataset/data.yaml', epochs = 100, batch = 16, imgsz = 640, save = True, project = '/content/drive/MyDrive/yolo_trainings', name = 'trying2')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
